# %% [markdown]
# ## Model creation

# %%
# !pip install tensorflow
# Out:
# ^C

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation
from tensoflow.keras.optimizers import Adam
from sklearn import metrics
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from tensorflow.keras.models import Sequential
#       2 from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation
#       3 from tensoflow.keras.optimizers import Adam
#       4 from sklearn import metrics
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
import numpy as np
# import tensorflow as tf

print(np.__version__)
# print(tf.__version__)
# Out:
# 2.4.6
# Collecting tensorflow
#   Downloading tensorflow-2.21.0-cp311-cp311-win_amd64.whl (350.8 MB)
#      -------------------------------------- 350.8/350.8 MB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in d:\coding\deeplearning\mediavenv\lib\site-packages (from tensorflow) (2.4.0)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: flatbuffers>=25.9.23 in d:\coding\deeplearning\mediavenv\lib\site-packages (from tensorflow) (25.12.19)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Downloading gast-0.7.0-py3-none-any.whl (22 kB)
# Collecting google_pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ---------------------------------------- 57.5/57.5 kB 3.1 MB/s eta 0:00:00
# Collecting libclang>=13.0.0
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
#      ---------------------------------------- 26.4/26.4 MB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: opt_einsum>=2.3.2 in d:\coding\deeplearning\mediavenv\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in d:\coding\deeplearning\mediavenv\lib\site-packages (from tensorflow) (26.2)
# Collecting protobuf<8.0.0,>=6.31.1
#   Downloading protobuf-7.35.1-cp310-abi3-win_amd64.whl (439 kB)
#      -------------------------------------- 440.0/440.0 kB 4.6 MB/s eta 0:00:00
# Collecting requests<3,>=2.21.0
#   Using cached requests-2.34.2-py3-none-any.whl (73 kB)
# Requirement already satisfied: setuptools in d:\coding\deeplearning\mediavenv\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in d:\coding\deeplearning\mediavenv\lib\site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in d:\coding\deeplearning\mediavenv\lib\site-packages (from tensorflow) (4.15.0)
# Collecting wrapt>=1.11.0
#   Downloading wrapt-2.2.1-cp311-cp311-win_amd64.whl (80 kB)
#      ---------------------------------------- 80.6/80.6 kB 4.4 MB/s eta 0:00:00
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.81.1-cp311-cp311-win_amd64.whl (4.9 MB)
#      ---------------------------------------- 4.9/4.9 MB 5.7 MB/s eta 0:00:00
# Collecting keras>=3.12.0
#   Downloading keras-3.14.1-py3-none-any.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.26.0 in d:\coding\deeplearning\mediavenv\lib\site-packages (from tensorflow) (2.4.6)
# Collecting h5py<3.15.0,>=3.11.0
#   Downloading h5py-3.14.0-cp311-cp311-win_amd64.whl (2.9 MB)
#      ---------------------------------------- 2.9/2.9 MB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in d:\coding\deeplearning\mediavenv\lib\site-packages (from tensorflow) (0.5.4)
# Collecting wheel<1.0,>=0.23.0
#   Using cached wheel-0.47.0-py3-none-any.whl (32 kB)
# Collecting rich
#   Downloading rich-15.0.0-py3-none-any.whl (310 kB)
#      -------------------------------------- 310.7/310.7 kB 4.8 MB/s eta 0:00:00
# Collecting namex
#   Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Collecting optree
#   Downloading optree-0.19.1-cp311-cp311-win_amd64.whl (337 kB)
#      -------------------------------------- 337.6/337.6 kB 7.0 MB/s eta 0:00:00
# Collecting charset_normalizer<4,>=2
#   Using cached charset_normalizer-3.4.7-cp311-cp311-win_amd64.whl (159 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.18-py3-none-any.whl (65 kB)
# Collecting urllib3<3,>=1.26
#   Using cached urllib3-2.7.0-py3-none-any.whl (131 kB)
# Requirement already satisfied: certifi>=2023.5.7 in d:\coding\deeplearning\mediavenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.6.17)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
#      ---------------------------------------- 91.7/91.7 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\coding\deeplearning\mediavenv\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, wrapt, wheel, urllib3, termcolor, protobuf, optree, mdurl, idna, h5py, grpcio, google_pasta, gast, charset_normalizer, requests, markdown-it-py, astunparse, rich, keras, tensorflow
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.9
#     Uninstalling protobuf-4.25.9:
#       Successfully uninstalled protobuf-4.25.9
# Successfully installed astunparse-1.6.3 charset_normalizer-3.4.7 gast-0.7.0 google_pasta-0.2.0 grpcio-1.81.1 h5py-3.14.0 idna-3.18 keras-3.14.1 libclang-18.1.1 markdown-it-py-4.2.0 mdurl-0.1.2 namex-0.1.0 optree-0.19.1 protobuf-7.35.1 requests-2.34.2 rich-15.0.0 tensorflow-2.21.0 termcolor-3.3.0 urllib3-2.7.0 wheel-0.47.0 wrapt-2.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mediapipe 0.10.14 requires protobuf<5,>=4.25.3, but you have protobuf 7.35.1 which is incompatible.
#
# [notice] A new release of pip available: 22.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
