# %% [markdown]
# ## Audio classification using machine leraning
#
# https://urbansounddataset.weebly.com/urbansound8k.html
#
# ###### Using Librosa library
#
# https://librosa.org/

# %%
# !pip install librosa
# Out:
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.7 MB 2.8 MB/s eta 0:00:01
#    ------------------- -------------------- 1.3/2.7 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.4/2.7 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 3.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/38.1 MB ? eta -:--:--
#     --------------------------------------- 0.8/38.1 MB 4.2 MB/s eta 0:00:09
#    - -------------------------------------- 1.6/38.1 MB 4.2 MB/s eta 0:00:09
#    -- ------------------------------------- 2.6/38.1 MB 4.3 MB/s eta 0:00:09
#    --- ------------------------------------ 3.7/38.1 MB 4.4 MB/s eta 0:00:08
#    ---- ----------------------------------- 4.2/38.1 MB 3.9 MB/s eta 0:00:09
#    ---- ----------------------------------- 4.5/38.1 MB 3.7 MB/s eta 0:00:10
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file_path = r"D:\Coding\DeepLearning\Datasets\UrbanSound8K\24074-1-0-4.wav"

# %%
import IPython.display as ipd

# %%
plt.figure(figsize=(12, 4))
ipd.Audio(file_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
import librosa.display

# %%
## horn
# Spectrogram
plt.figure(figsize=(12, 4))
data, sample_rate = librosa.load(file_path)
librosa.display.waveshow(data, sr=sample_rate)
ipd.Audio(file_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data
# Out:
# array([-0.02061145, -0.03201887, -0.03072608, ..., -0.01214315,
#        -0.0188606 , -0.03248132], shape=(88200,), dtype=float32)

# %%
sample_rate
# Out:
# 22050

# %%
from scipy.io import wavfile as wav
sample_rate, wave_data = wav.read(file_path)
print(sample_rate)
wave_data
# Out:
# 44100
# array([[-1077,  -767],
#        [-1119,  -725],
#        [-1256,  -700],
#        ...,
#        [-1222,  -397],
#        [-1252,  -722],
#        [-1259, -1052]], shape=(176400, 2), dtype=int16)

# %%
import pandas as pd
meta_path = r"D:\Coding\DeepLearning\Datasets\UrbanSound8K\metadata\UrbanSound8K.csv"
metadata = pd.read_csv(meta_path)
metadata.head()
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %%
## check whether the dataset is balanced
metadata['class'].value_counts()
# Out:
# class
# dog_bark            1000
# children_playing    1000
# air_conditioner     1000
# street_music        1000
# engine_idling       1000
# jackhammer          1000
# drilling            1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: count, dtype: int64
